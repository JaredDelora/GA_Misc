# %%
# Import libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %matplotlib inline

# %%
df = pd.read_csv('./data/hackathon.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         32561 non-null  int64
#  1   fnlwgt                      32561 non-null  int64
#  2   education                   32561 non-null  object
#  3   education-num               32561 non-null  int64
#  4   marital-status              32561 non-null  object
#  5   occupation                  32561 non-null  object
#  6   relationship                32561 non-null  object
#  7   sex                         32561 non-null  object
#  8   capital-gain                32561 non-null  int64
#  9   capital-loss                32561 non-null  int64
#  10  hours-per-week              32561 non-null  int64
#  11  native-country              32561 non-null  object
#  12  wage                        32561 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'wage', 'workclass_?',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_Without-pay', 'workclass-govt',
#        'married', 'single', 'separated', 'US', 'male', 'fnlwgt^2',
#        'hours-per-week^2'],
#       dtype='object')

# %%
plt.matplotlib.pyplot.plot(df['age'])

# %%
# # heatmap of correlations to 
sns.heatmap(df.corr())[['workclass']].sort_values(()'workclass', ascending = False ),annot = True,
           cmap = 'coolwarm',
           vmin = -1,
           vmax = 1
          ));
# Out:
#   File "<ipython-input-41-429660945f05>", line 2
#     sns.heatmap(df.corr())[['workclass']].sort_values(('workclass', ascending = False),annot = True,
#                                                                               ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(4,8))
sns.heatmap(df.corr()[['wage']].
            sort_values(by='wage', ascending=False),cmap='coolwarm', annot=True, vmin=-1);

# %%
sns.pairplot(df, x_vars=['age', 'sex'], y_vars='education-num', kind='reg');
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-9-edca6fb5e45b> in <module>
# ----> 1 sns.pairplot(df, x_vars=['age', 'sex'], y_vars='education-num', kind='reg');
#
# ~\anaconda3\envs\dsi\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124     elif kind == "reg":
#    2125         from .regression import regplot  # Avoid circular import
# -> 2126         plotter(regplot, **plot_kws)
#    2127
#    2128     # Add a legend
#
# ~\anaconda3\envs\dsi\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1355         row_indices, col_indices = np.indices(self.axes.shape)
#    1356         indices = zip(row_indices.flat, col_indices.flat)
# ...

# %%
plt.figure(figsize=(16,10))
ax = sns.barplot(x='hours-per-week', y="sex", data=temp, palette="Blues_d")
# plt.barh(temp.index, temp['coef'])
plt.title('Hours worked per week / Sex', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=14)
plt.xlabel('Hours Per Week', fontsize=20)
plt.ylabel('Sex', fontsize=20)
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.figure(figsize=(16,10))
ax = sns.barplot(x='education-num', y="hours-per-week", data=temp, palette="Blues_d")
# plt.barh(temp.index, temp['coef'])
plt.title('Hours worked per week / Education Number', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=14)
plt.xlabel('Wage', fontsize=20)
plt.ylabel('EducationNumber', fontsize=20)
# Out:
# Text(0, 0.5, 'Hours per week')
